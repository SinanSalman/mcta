# %%
import mcta
import mcta_rw
import timeit
base = 'AD'
Settings, JSON_Map, GeoJSON_Map = mcta_rw.LoadDataFiles(base)
lengths, lanes, FFS, P = mcta.SetupMCTA(JSON_Map, GeoJSON_Map, Verbose=False)

def A():
    mcta.SolveMCTA(lengths, lanes, P, \
                   VehiclesCount=JSON_Map['VehiclesCountEst'],\
                   Objectives=['D','K','C','PI'], SkipChecksForSpeed=False)

def B():
    mcta.SolveMCTA(lengths, lanes, P, \
                   VehiclesCount=JSON_Map['VehiclesCountEst'],\
                   Objectives=['D','K'], SkipChecksForSpeed=True)
# %prun a=timeit.timeit(A,number=100)
# b=timeit.timeit(B,number=100)
print(f'a={a}\nb={b},\ndiff={a-b} ({(a-b)/a*100:.4}% saved)')
# Out:
# 	looking in: /Users/sinan/Dropbox (WorkDropbox)/SustainableLogistics/Analysis and Experiments/Code/mcta/
# 	reading configurations and rules from mcta_vis_cfg.json file...
# 	reading AD-Map.json
# 	reading AD-Map.geojson
#  a=42.56636944899992
# b=6.567003104000037,
# diff=35.999366344999885 (84.57% saved)
#          52255323 function calls (52254922 primitive calls) in 42.567 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       100   16.423    0.164   35.950    0.359 mcta.py:246(_MFPT)
#  25884900   13.710    0.000   16.222    0.000 defmatrix.py:191(__getitem__)
#       100    5.595    0.056    5.707    0.057 decomp.py:118(eig)
#  25899802    2.515    0.000    2.516    0.000 {built-in method builtins.isinstance}
#       200    1.626    0.008    1.630    0.008 linalg.py:1468(svd)
#      1200    1.030    0.001    1.031    0.001 {built-in method numpy.dot}
# ...
